# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`
#
# mongoimport --type json -d uk_food -c establishments --drop --jsonArray ./Resources/establishments.json

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
from tavneet_mongo_login import tavneet_login_mongo

# %%
# Create an instance of MongoClient
mongo = MongoClient(tavneet_login_mongo)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['autosaurus', 'classDB', 'fruits_db', 'project3_group4', 'uk_food', 'admin', 'local']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
print(db.establishments.find_one())
# Out:
# {'_id': ObjectId('67a6b4d2485bb01e2fe8bf74'), 'FHRSID': 254719, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000069980', 'BusinessName': 'Refreshment Kiosk', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'The Bay', 'AddressLine2': 'St Margarets Bay', 'AddressLine3': 'Kent', 'AddressLine4': '', 'PostCode': 'CT15 6DY', 'Phone': '', 'RatingValue': '5', 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-03-24T00:00:00', 'LocalAuthorityCode': '182', 'LocalAuthorityName': 'Dover', 'LocalAuthorityWebSite': 'http://www.dover.gov.uk/', 'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk', 'scores': {'Hygiene': 0, 'Structural': 5, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '1.387974', 'latitude': '51.152225'}, 'RightToReply': '', 'Distance': 4587.347174863443, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'tot
# ...

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
penang_flavours_dict = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(penang_flavours_dict)
# Out:
# InsertOneResult(ObjectId('67a6b6dc7f96cf391d73929b'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
check = {"BusinessName":"Penang Flavours"}
results_check = establishments.find(check)
for r in results_check:
    print(r)
# Out:
# {'_id': ObjectId('67a6b6dc7f96cf391d73929b'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': '', 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query_1 = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields_1 = {'BusinessTypeID': 1,'BusinessType': 1}
results_1 = list(establishments.find(query_1,fields_1))
for r in results_1:
    pprint(r)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf74')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf77')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf79')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf7a')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf7b')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf7c')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf7d')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('67a6b4d2485bb01e2fe8bf7e')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one({'BusinessName': 'Penang Flavours'}, { '$set' : {'BusinessTypeID': 1}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738979075, 20), 't': 598}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738979075, 20), 'signature': {'hash': b'9\xa6\xc9\xc2D\xf5Rw\xe0L\xd2\xfb\xb9\\\xd4\xd8\xd2<\x82\x98', 'keyId': 7413003451409367042}}, 'operationTime': Timestamp(1738979075, 20), 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
check = {"BusinessName":"Penang Flavours"}
results_check = establishments.find(check)
for r in results_check:
    print(r)
# Out:
# {'_id': ObjectId('67a6b6dc7f96cf391d73929b'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1, 'AddressLine1': 'Penang Flavours', 'AddressLine2': '146A Plumstead Rd', 'AddressLine3': 'London', 'AddressLine4': '', 'PostCode': 'SE18 7DY', 'Phone': '', 'LocalAuthorityCode': '511', 'LocalAuthorityName': 'Greenwich', 'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk', 'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk', 'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''}, 'SchemeType': 'FHRS', 'geocode': {'longitude': '0.08384000', 'latitude': '51.49014200'}, 'RightToReply': '', 'Distance': 4623.972328074718, 'NewRatingPending': True}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query_2 = {'LocalAuthorityName': 'Dover'}
results_2 = establishments.count_documents(query_2)
print(results_2)
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query_2)
# Out:
# DeleteResult({'n': 994, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738979102, 177), 't': 598}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738979102, 182), 'signature': {'hash': b'\xcd\xef\x99,\x942\xd4\xa1\x81\xdf\x0b\x93\xbc\xea\x0f#\xca\xa8Tc', 'keyId': 7413003451409367042}}, 'operationTime': Timestamp(1738979102, 177)}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
check_2 = establishments.find(query_2)
for c in check_2:
    print(c)

# %%
# Check that other documents remain with 'find_one'
check_3 = establishments.find_one()
pprint(check_3)
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('67a6b4d2485bb01e2fe8c25b'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
# ...

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},[{'$set': {'geocode.longitude': {'$toDouble': '$geocode.longitude'},
                                         'geocode.latitude': {'$toDouble': '$geocode.latitude'}}}])
# Out:
# UpdateResult({'n': 38786, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738979136, 866), 't': 598}, 'nModified': 38786, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738979136, 866), 'signature': {'hash': b'\xb9.\tn\x04\x1d\x83\xf0\n\xb2(fX;\x17\xd3V\xfd\xf1\xee', 'keyId': 7413003451409367042}}, 'operationTime': Timestamp(1738979136, 866), 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
#find the all unique values in RatingValue field
unique_values = establishments.distinct('RatingValue')
pprint(unique_values)
# Out:
# ['0',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  'Awaiting Inspection',
#  'AwaitingInspection',
#  'AwaitingPublication',
#  'Exempt',
#  'Pass']

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ['Awaiting Inspection','AwaitingInspection','AwaitingPublication','Exempt','Pass']

establishments.update_many({'RatingValue':{'$in':non_ratings}},[{'$set': {'RatingValue': None}}])
# Out:
# UpdateResult({'n': 4091, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738979212, 4141), 't': 598}, 'nModified': 4091, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738979212, 4141), 'signature': {'hash': b"\x08\x85RY\x90\xa0\xac:\x07&nF\x1c\xf6\xc2\xd6'Q\x9dO", 'keyId': 7413003451409367042}}, 'operationTime': Timestamp(1738979212, 4141), 'updatedExisting': True}, acknowledged=True)

# %%
#check i f non 1-5 rating values are set to null
unique_values = establishments.distinct('RatingValue')
pprint(unique_values)
# Out:
# [None, '0', '1', '2', '3', '4', '5']

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many( {}, [{ '$set': {'RatingValue': {'$toInt': '$RatingValue'} }}])
# Out:
# UpdateResult({'n': 38786, 'electionId': ObjectId('7fffffff0000000000000256'), 'opTime': {'ts': Timestamp(1738979406, 1382), 't': 598}, 'nModified': 34694, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1738979406, 1382), 'signature': {'hash': b'\xe1Mg\xa5\xfe_\x82SJ\x96#\x8d\xc3p~\xbc0\x98\x08U', 'keyId': 7413003451409367042}}, 'operationTime': Timestamp(1738979406, 1382), 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
count = 0  # Initialize a counter
for document in establishments.find():
    longitude = document.get('geocode', {}).get('longitude')  
    latitude = document.get('geocode', {}).get('latitude')    
    rating_value = document.get('RatingValue')
    
    print(f"Longitude: {longitude}, Type: {type(longitude)}")
    print(f"Latitude: {latitude}, Type: {type(latitude)}")
    print(f"Rating Value: {rating_value}, Type: {type(rating_value)}")
    
    count += 1  # Increment the counter
    if count >= 1:  # Check if we've printed 10 documents
        break  # Exit the loop
# Out:
# Longitude: 1.195625, Type: <class 'float'>
# Latitude: 51.083812, Type: <class 'float'>
# Rating Value: 5, Type: <class 'int'>
